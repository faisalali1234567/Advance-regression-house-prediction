# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
# df1 = pd.read_csv("test.csv")

# %%
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Conversion of numerical data into int data

# %% [markdown]
# # one hot encoder
# we dont use the one hot encoder
# reason
# example if MSZoning has 3 inner attributr types this wil create 3 more colms it does the same for all other colums

# %%
# df = pd.get_dummies(df.MSZoning)

# %%
#df1.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ### Label encoder

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
# le  = LabelEncoder()

# %%
# df.MSZoning = le.fit_transform(df.MSZoning)

# %% [markdown]
# ### General form to convert the catogorical data into the numerical manner

# %%
from sklearn.preprocessing import LabelEncoder

def label_encode_dataframe(df):
    le = LabelEncoder()
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = le.fit_transform(df[column])
    return df

# Example usage:
# df is your DataFrame
df = label_encode_dataframe(df)
# the below data has been converted into numerical format

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int32
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int32
#  6   Alley          1460 non-null   int32
#  7   LotShape       1460 non-null   int32
#  8   LandContour    1460 non-null   int32
#  9   Utilities      1460 non-null   int32
#  10  LotConfig      1460 non-null   int32
#  11  LandSlope      1460 non-null   int32
#  12  Neighborhood   1460 non-null   int32
#  13  Condition1     1460 non-null   int32
#  14  Condition2     1460 non-null   int32
#  15  BldgType       1460 non-null   int32
#  16  HouseStyle     1460 non-null   int32
#  17  OverallQual    1460 non-null   int64
# ...

# %%
#df.astype("category") this is the old version of sklearn new version automatically converts into category we can check this by info method

# %%
#df.astype("int")

# %%
# data= np.array([df])

# %%
df.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1460.000000  1460.000000  1460.000000  1201.000000    1460.000000
# mean    730.500000    56.897260     3.028767    70.049958   10516.828082
# std     421.610009    42.300571     0.632017    24.284752    9981.264932
# min       1.000000    20.000000     0.000000    21.000000    1300.000000
# 25%     365.750000    20.000000     3.000000    59.000000    7553.500000
# 50%     730.500000    50.000000     3.000000    69.000000    9478.500000
# 75%    1095.250000    70.000000     3.000000    80.000000   11601.500000
# max    1460.000000   190.000000     4.000000   313.000000  215245.000000
#
#             Street        Alley     LotShape  LandContour    Utilities  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean      0.995890     1.903425     1.942466     2.777397     0.000685  ...
# std       0.063996     0.394776     1.409156     0.707666     0.026171  ...
# ...

# %%
df.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1      2         3
# 1   2          20         3         80.0     9600       1      2         3
# 2   3          60         3         68.0    11250       1      2         0
# 3   4          70         3         60.0     9550       1      2         0
# 4   5          60         3         84.0    14260       1      2         0
# 5   6          50         3         85.0    14115       1      2         0
# 6   7          20         3         75.0    10084       1      2         3
# 7   8          60         3          NaN    10382       1      2         0
# 8   9          50         4         51.0     6120       1      2         3
# 9  10         190         3         50.0     7420       1      2         3
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# ...

# %%
df['Street']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1455    1
# 1456    1
# 1457    1
# 1458    1
# 1459    1
# Name: Street, Length: 1460, dtype: int32

# %%
df['Street'].value_counts()
# Out:
# Street
# 1    1454
# 0       6
# Name: count, dtype: int64

# %%
df['CentralAir'].value_counts()
# Out:
# CentralAir
# 1    1365
# 0      95
# Name: count, dtype: int64

# %%
df['Alley'].value_counts()
# Out:
# Alley
# 2    1369
# 0      50
# 1      41
# Name: count, dtype: int64

# %%
df['LandSlope'].value_counts()
# Out:
# LandSlope
# 0    1382
# 1      65
# 2      13
# Name: count, dtype: int64

# %%
df['LotConfig'].value_counts()
# Out:
# LotConfig
# 4    1052
# 0     263
# 1      94
# 2      47
# 3       4
# Name: count, dtype: int64

# %%
df["PoolQC"].value_counts()
# Out:
# PoolQC
# 3    1453
# 2       3
# 0       2
# 1       2
# Name: count, dtype: int64

# %% [markdown]
# ### Ploting

# %%
# %matplotlib inline

# %%
import matplotlib as plt

# %% [markdown]
# ### Plotting of histograms

# %%
df.hist(bins = 50, figsize = (100,100))
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'MSSubClass'}>,
#         <Axes: title={'center': 'MSZoning'}>,
#         <Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'LotArea'}>,
#         <Axes: title={'center': 'Street'}>,
#         <Axes: title={'center': 'Alley'}>,
#         <Axes: title={'center': 'LotShape'}>,
#         <Axes: title={'center': 'LandContour'}>],
#        [<Axes: title={'center': 'Utilities'}>,
#         <Axes: title={'center': 'LotConfig'}>,
#         <Axes: title={'center': 'LandSlope'}>,
#         <Axes: title={'center': 'Neighborhood'}>,
#         <Axes: title={'center': 'Condition1'}>,
#         <Axes: title={'center': 'Condition2'}>,
#         <Axes: title={'center': 'BldgType'}>,
#         <Axes: title={'center': 'HouseStyle'}>,
#         <Axes: title={'center': 'OverallQual'}>],
#        [<Axes: title={'center': 'OverallCond'}>,
#         <Axes: title={'center': 'YearBuilt'}>,
# ...

# %% [markdown]
# ### Missing atributes

# %% [markdown]
# ### Train test split (we skip)
# AS we already have train and test data sets separated we don't split the data again

# %% [markdown]
# ### Stratified sampling (we skip)
# we use stratified sampling in order to split the data into a proper manner of testing and training data set but the given data is already in a proper manner
#
# came to this conclusion by looking into the above graph and some basic info about the data

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### co-relation of the attributes
# we do this to understand the importance of the particular attribute with respect to the output label value

# %%
corr_matrix = df.corr() #onlynumeric = True

# %%
corr_matrix['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
#                   ...
# FireplaceQu    -0.459605
# GarageFinish   -0.549247
# KitchenQual    -0.589189
# BsmtQual       -0.620886
# ExterQual      -0.636884
# Name: SalePrice, Length: 81, dtype: float64

# %% [markdown]
# ### splitting the atributes and the labels

# %%
# df1= df.drop('SalePrice' ,axis = 1).copy()

# %%
# df_label = df['SalePrice'].copy()

# %%
# df1.shape

# %% [markdown]
# ### plotting a scatter matrix
# we plot the scatter matrix in order to understand which attribute is important and if the missing data is present then we can drop it or not

# %%
from pandas.plotting import scatter_matrix
attr = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'FireplaceQu', 'GarageFinish', 'KitchenQual', 'BsmtQual', 'ExterQual']
scatter_matrix(df[attr],figsize = (20,20))
# Out:
# array([[<Axes: xlabel='SalePrice', ylabel='SalePrice'>,
#         <Axes: xlabel='OverallQual', ylabel='SalePrice'>,
#         <Axes: xlabel='GrLivArea', ylabel='SalePrice'>,
#         <Axes: xlabel='GarageCars', ylabel='SalePrice'>,
#         <Axes: xlabel='GarageArea', ylabel='SalePrice'>,
#         <Axes: xlabel='FireplaceQu', ylabel='SalePrice'>,
#         <Axes: xlabel='GarageFinish', ylabel='SalePrice'>,
#         <Axes: xlabel='KitchenQual', ylabel='SalePrice'>,
#         <Axes: xlabel='BsmtQual', ylabel='SalePrice'>,
#         <Axes: xlabel='ExterQual', ylabel='SalePrice'>],
#        [<Axes: xlabel='SalePrice', ylabel='OverallQual'>,
#         <Axes: xlabel='OverallQual', ylabel='OverallQual'>,
#         <Axes: xlabel='GrLivArea', ylabel='OverallQual'>,
#         <Axes: xlabel='GarageCars', ylabel='OverallQual'>,
#         <Axes: xlabel='GarageArea', ylabel='OverallQual'>,
#         <Axes: xlabel='FireplaceQu', ylabel='OverallQual'>,
# ...

# %%
df.plot(kind ="scatter" , x = "OverallQual" , y = "SalePrice" , alpha = 0.9) # alpha indicates the darker colours of tyhe output
# Out:
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %% [markdown]
# ##### we can also try up for the new attributes by just arthematic opertaions on the existing attributes
# ##### so by the above graph we can see tht the relation is strongly co-related

# %%
df.plot(kind ="scatter" , x = "ExterQual" , y = "SalePrice" , alpha = 0.9)
# Out:
# <Axes: xlabel='ExterQual', ylabel='SalePrice'>

# %%
df.plot(kind ="scatter" , x = "LotFrontage" , y = "SalePrice" , alpha = 0.9)
# Out:
# <Axes: xlabel='LotFrontage', ylabel='SalePrice'>

# %% [markdown]
# #### only one data attribute is mising that is LotFrontage

# %% [markdown]
# #### we can just use meadian normal trick but generally let us use create a pipeline system system

# %%
median =df['LotFrontage'].median()
median
# Out:
# 69.0

# %%
df['LotFrontage'].fillna(median) # we can replave it by adding .replace =True
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %% [markdown]
# ### Splitting up of the labels and the attributes

# %%
df1 = df.drop('SalePrice' ,axis = 1).copy()
df1_labels = df['SalePrice'].copy()

# %% [markdown]
# ## Creation of pipeline system

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([('imputer',SimpleImputer(strategy = 'median' )),('std_scaler',StandardScaler())])

# %%
df2 = my_pipeline.fit_transform(df1)

# %%
df2.shape
# Out:
# (1460, 80)

# %% [markdown]
# After the excution of every tranformer we have to create a new data frame will be commented
# #### Creation of new dataframe reference

# %%
# my_pipeline.fit(df2)

# %%
# x = my_pipeline.transform(df2)

# %%
# df3 = pd.DataFrame(x , columns = df.columns)

# %%
# df3.head(10)

# %%
# here the dataframe shld be created for the main data without splitting the data and we will hv the label also in it so again if we use this technique we must separate the labels again

# %%
# df3.describe()

# %% [markdown]
# #### checking the values of the attributes before missing values and after the values

# %%
# df2.plot(kind = "scatter" , x = "LotFrontage" , y = "SalePrice" ,alpha = 0.9)

# %% [markdown]
# ## Selecting the best model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
model = RandomForestRegressor()
# model = GradientBoostingRegressor()
model.fit(df2,df1_labels)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### checking the df2 and the values of the df_label)

# %%
df1.iloc[ : 5]
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1      2         3
# 1   2          20         3         80.0     9600       1      2         3
# 2   3          60         3         68.0    11250       1      2         0
# 3   4          70         3         60.0     9550       1      2         0
# 4   5          60         3         84.0    14260       1      2         0
#
#    LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  Fence  \
# 0            3          0  ...            0         0       3      4
# 1            3          0  ...            0         0       3      4
# 2            3          0  ...            0         0       3      4
# 3            3          0  ...            0         0       3      4
# 4            3          0  ...            0         0       3      4
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df1_labels.iloc[ :5]
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
# ### We are gonna check how model is predicting the value

# %%
somedata = df1.iloc[ : 5]
some_labels = df1_labels.iloc[ :5]
prepare_data = my_pipeline.transform(somedata)
model.predict(prepare_data)
# Out:
# array([207623.  , 176009.37, 222067.87, 157235.97, 261818.17])

# %%
list(some_labels)
# Out:
# [208500, 181500, 223500, 140000, 250000]

# %% [markdown]
# #### Evaluating the model using RMSE value

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
df2_predictions = model.predict(df2)
mse =mean_squared_error(df1_labels,df2_predictions)
rmse = np.sqrt(mse)

# %%
# if the rmse value is 0 the the model had overfitted on it and it can just predict the values easily

# %%
mse
# Out:
# 111116698.23920923

# %%
rmse
# Out:
# 10541.190551318634

# %% [markdown]
# ##### RMSE Randomforest = 10751       , Gradientboosting = 15128
# ##### so we r selecting the Randomforest model

# %% [markdown]
# ##### As we can see the good model we can get was randomforest we will leave  Cross Validation technique as the overfitting of the data is not done

# %% [markdown]
# ## Save the model

# %%
from joblib import dump, load
dump(model, 'priceprediction.joblib')
# Out:
# ['priceprediction.joblib']

# %% [markdown]
# ### Testing the model on the training dataset

# %%
df3 = pd.read_csv("test.csv")

# %%
df3.shape
# Out:
# (1459, 80)

# %%
df3.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %% [markdown]
# #### Label_encoder for test data

# %%
def label_encode_dataframe(df3):
    le = LabelEncoder()
    for column in df3.columns:
        if df3[column].dtype == 'object':
            df3[column] = le.fit_transform(df3[column])
    return df3

# Example usage:
# df is your DataFrame
df3 = label_encode_dataframe(df)

# %% [markdown]
# #### Splitting of the data

# %%
df3_attributes = df3.drop("SalePrice" , axis = 1)
df3_labels = df3["SalePrice"]

# %%
df3_labels
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# #### taking care of missing data in testset

# %%
df4 = my_pipeline.fit_transform(df3_attributes)

# %%
df4.shape
# Out:
# (1460, 80)

# %%
df3_labels.shape
# Out:
# (1460,)

# %%
df3_predictions = model.predict(df4)
mse  = mean_squared_error(df3_predictions,df3_labels)
rmse = np.sqrt(mse)

# %%
df3_predictions
# Out:
# array([207623.  , 176009.37, 222067.87, ..., 261525.35, 140090.05,
#        149943.  ])

# %%
df3_labels
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
mse
# Out:
# 111116698.23920923

# %%
rmse
# Out:
# 10541.190551318634

# %%
a =(df3["Id"])

# %%
b=df3_predictions

# %% [markdown]
# #### Adding up of the values of the predicted value as a new attribute to the data frame

# %%
df3["df3_predictions"] = df3_predictions

# %%
# print(b.to_string())

# %%
#.to_string will print the output value of the given table entirely

# %%
print(df3.iloc[:,-1].to_string())
# Out:
# 0       207623.00
# 1       176009.37
# 2       222067.87
# 3       157235.97
# 4       261818.17
# 5       144973.00
# 6       304139.43
# 7       210574.90
# 8       142242.50
# 9       118997.59
# 10      130877.50
# 11      351700.52
# 12      138827.00
# 13      252618.51
# 14      154009.00
# 15      140000.50
# 16      147184.50
# 17      100252.00
# 18      157158.00
# 19      139979.00
# 20      322893.24
# 21      146217.15
# 22      232627.00
# 23      132656.37
# 24      150227.75
# 25      254958.87
# 26      131689.00
# 27      302241.11
# 28      198272.50
# 29       68583.11
# 30       62233.58
# 31      145411.00
# 32      194292.79
# 33      166895.55
# 34      284444.50
# 35      308468.42
# 36      145539.87
# 37      153085.74
# 38      117656.00
# 39       86378.50
# 40      157911.32
# 41      162514.50
# 42      143534.00
# 43      128633.00
# 44      139594.00
# 45      302931.17
# 46      251630.27
# 47      248222.28
# 48      117108.51
# 49      127992.00
# ...

# %%
print(df["Id"],df["df3_predictions"])
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1455    1456
# 1456    1457
# 1457    1458
# 1458    1459
# 1459    1460
# Name: Id, Length: 1460, dtype: int64 0       207623.00
# 1       176009.37
# 2       222067.87
# 3       157235.97
# 4       261818.17
#           ...
# 1455    176029.40
# 1456    202101.74
# 1457    261525.35
# 1458    140090.05
# 1459    149943.00
# Name: df3_predictions, Length: 1460, dtype: float64

# %%
Id = df3["Id"]

# %%
sub = pd.DataFrame()
sub['Id'] = Id
sub['SalePrice'] = df3_predictions
sub.to_csv('submission.csv', index = False)

# %%
print(sub.to_string())
# Out:
#         Id  SalePrice
# 0        1  207623.00
# 1        2  176009.37
# 2        3  222067.87
# 3        4  157235.97
# 4        5  261818.17
# 5        6  144973.00
# 6        7  304139.43
# 7        8  210574.90
# 8        9  142242.50
# 9       10  118997.59
# 10      11  130877.50
# 11      12  351700.52
# 12      13  138827.00
# 13      14  252618.51
# 14      15  154009.00
# 15      16  140000.50
# 16      17  147184.50
# 17      18  100252.00
# 18      19  157158.00
# 19      20  139979.00
# 20      21  322893.24
# 21      22  146217.15
# 22      23  232627.00
# 23      24  132656.37
# 24      25  150227.75
# 25      26  254958.87
# 26      27  131689.00
# 27      28  302241.11
# 28      29  198272.50
# 29      30   68583.11
# 30      31   62233.58
# 31      32  145411.00
# 32      33  194292.79
# 33      34  166895.55
# 34      35  284444.50
# 35      36  308468.42
# 36      37  145539.87
# 37      38  153085.74
# 38      39  117656.00
# 39      40   86378.50
# ...
